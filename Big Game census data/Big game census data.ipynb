# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df= pd.read_csv(r'Big Game Census data2.csv')

# %%
df.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...

# %%
df.shape
# Out:
# (121, 24)

# %%
df.dtypes
# Out:
# Player Name                                                  object
# Player Jersey Number                                         object
# Player Position                                              object
# Player Age                                                  float64
# Player Weight (lbs.)                                        float64
# Years Played                                                 object
# Player Birthplace (city, town, etc.)                         object
# Player Birth State                                           object
# Player Birthplace (Combo)                                    object
# Player College                                               object
# Player Team                                                  object
# Conference                                                   object
# 2016 Population Estimates (except where otherwise noted)     object
# State GEO ID                                                float64
# ...

# %%
df.isnull().sum()
# Out:
# Player Name                                                 2
# Player Jersey Number                                        3
# Player Position                                             3
# Player Age                                                  3
# Player Weight (lbs.)                                        3
# Years Played                                                3
# Player Birthplace (city, town, etc.)                        3
# Player Birth State                                          3
# Player Birthplace (Combo)                                   3
# Player College                                              3
# Player Team                                                 3
# Conference                                                  3
# 2016 Population Estimates (except where otherwise noted)    3
# State GEO ID                                                3
# Full GEOID                                                  3
# ...

# %%
df=df.dropna(how='all')

# %%
df.shape
# Out:
# (119, 24)

# %%
df.corr()
# Out:
#                                Player Age  Player Weight (lbs.)  State GEO ID  \
# Player Age                       1.000000             -0.016997      0.027805
# Player Weight (lbs.)            -0.016997              1.000000      0.163214
# State GEO ID                     0.027805              0.163214      1.000000
# Latitude (player birthplace)     0.085980             -0.033874      0.005716
# Longitude (player birthplace)    0.083444             -0.136517      0.251143
# Number from City                 0.049584             -0.147419     -0.082166
# Number of Records                     NaN                   NaN           NaN
#
#                                Latitude (player birthplace)  \
# Player Age                                         0.085980
# Player Weight (lbs.)                              -0.033874
# State GEO ID                                       0.005716
# Latitude (player birthplace)                       1.000000
# ...

# %%
df.describe()
# Out:
#        Player Age  Player Weight (lbs.)  State GEO ID  \
# count  118.000000            118.000000    118.000000
# mean    26.720339            243.881356     28.330508
# std      3.653556             45.959322     17.071521
# min     21.000000            167.000000      1.000000
# 25%     24.000000            205.000000     12.000000
# 50%     26.000000            238.000000     31.000000
# 75%     29.000000            274.000000     40.500000
# max     40.000000            350.000000     75.000000
#
#        Latitude (player birthplace)  Longitude (player birthplace)  \
# count                    118.000000                     118.000000
# mean                      35.566567                     -92.820792
# std                        7.449830                      20.707252
# min                      -14.252294                    -170.713450
# 25%                       32.416135                     -97.764743
# 50%                       36.164258                     -86.614908
# ...

# %%
df.nunique()
# Out:
# Player Name                                                 119
# Player Jersey Number                                         83
# Player Position                                              45
# Player Age                                                   17
# Player Weight (lbs.)                                         68
# Years Played                                                 17
# Player Birthplace (city, town, etc.)                        109
# Player Birth State                                           35
# Player Birthplace (Combo)                                   110
# Player College                                               75
# Player Team                                                   2
# Conference                                                    2
# 2016 Population Estimates (except where otherwise noted)    110
# State GEO ID                                                 35
# Full GEOID                                                   35
# ...

# %%
df1=df.drop(['Number from City','Number of Records',
       'American FactFinder Link for more Census data points',
       'Quickfacts Link', 'State Data Link', 'Source (Population States 2017)',
       'Birthplace, Population Data Source','Player Birthplace (Combo)' ], axis =1)

# %%
df1.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State Player College  Player Team Conference  \
# ...

# %%
df2= pd.read_excel(r'All Places Census 2016 Population Estimates.xlsx')

# %%
df2.head()
# Out:
#       Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0  1620000US0100124   100124            Abbeville city, Alabama
# 1  1620000US0100460   100460           Adamsville city, Alabama
# 2  1620000US0100484   100484              Addison town, Alabama
# 3  1620000US0100676   100676                Akron town, Alabama
# 4  1620000US0100820   100820            Alabaster city, Alabama
#
#   April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 0                   2688                            2688
# 1                   4522                            4522
# 2                    758                             756
# 3                    356                             356
# 4                  30352                           31066
#
#    Population Estimate (as of July 1) - 2010  \
# 0                                       2683
# 1                                       4517
# 2                                        754
# 3                                        355
# ...

# %%
df2.columns
# Out:
# Index(['Geographic ID', 'GEOID 2', 'Geography, full name (City, State)',
#        'April 1, 2010 - Census', 'April 1, 2010 - Estimates Base',
#        'Population Estimate (as of July 1) - 2010',
#        'Population Estimate (as of July 1) - 2011',
#        'Population Estimate (as of July 1) - 2012',
#        'Population Estimate (as of July 1) - 2013',
#        'Population Estimate (as of July 1) - 2014',
#        'Population Estimate (as of July 1) - 2015',
#        'Population Estimate (as of July 1) - 2016'],
#       dtype='object')

# %%
df2.drop(['April 1, 2010 - Census', 'April 1, 2010 - Estimates Base',
       'Population Estimate (as of July 1) - 2010',
       'Population Estimate (as of July 1) - 2011',
       'Population Estimate (as of July 1) - 2012',
       'Population Estimate (as of July 1) - 2013',
       'Population Estimate (as of July 1) - 2014',
       'Population Estimate (as of July 1) - 2015'], axis=1)
# Out:
#           Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0      1620000US0100124   100124            Abbeville city, Alabama
# 1      1620000US0100460   100460           Adamsville city, Alabama
# 2      1620000US0100484   100484              Addison town, Alabama
# 3      1620000US0100676   100676                Akron town, Alabama
# 4      1620000US0100820   100820            Alabaster city, Alabama
# ...                 ...      ...                                ...
# 19505  1620000US5681300  5681300            Wamsutter town, Wyoming
# 19506  1620000US5683040  5683040            Wheatland town, Wyoming
# 19507  1620000US5684925  5684925              Worland city, Wyoming
# 19508  1620000US5685015  5685015               Wright town, Wyoming
# 19509  1620000US5686665  5686665                Yoder town, Wyoming
#
#        Population Estimate (as of July 1) - 2016
# 0                                           2603
# 1                                           4360
# ...

# %%
df2.to_csv('Clean game data estimate 2016.csv', index=False)

# %%
df3=pd.read_excel(r'All states Census 2017 Population Estimates.xlsx')
df3.head()
# Out:
#          GEOID  GEOID2 Geography Name  April 1, 2010 - Census  \
# 0  0400000US01       1        Alabama                 4779736
# 1  0400000US02       2         Alaska                  710231
# 2  0400000US04       4        Arizona                 6392017
# 3  0400000US05       5       Arkansas                 2915918
# 4  0400000US06       6     California                37253956
#
#    April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010  \
# 0                         4780135                                    4785579
# 1                          710249                                     714015
# 2                         6392309                                    6407002
# 3                         2916031                                    2921737
# 4                        37254518                                   37327690
#
#    Population Estimate (as of July 1) - 2011  \
# 0                                    4798649
# ...

# %%
df3.columns
# Out:
# Index(['GEOID', 'GEOID2', 'Geography Name', 'April 1, 2010 - Census',
#        'April 1, 2010 - Estimates Base',
#        'Population Estimate (as of July 1) - 2010',
#        'Population Estimate (as of July 1) - 2011',
#        'Population Estimate (as of July 1) - 2012',
#        'Population Estimate (as of July 1) - 2013',
#        'Population Estimate (as of July 1) - 2014',
#        'Population Estimate (as of July 1) - 2015',
#        'Population Estimate (as of July 1) - 2016',
#        'Population Estimate (as of July 1) - 2017'],
#       dtype='object')

# %%
df3.drop(['April 1, 2010 - Census',
       'April 1, 2010 - Estimates Base',
       'Population Estimate (as of July 1) - 2010',
       'Population Estimate (as of July 1) - 2011',
       'Population Estimate (as of July 1) - 2012',
       'Population Estimate (as of July 1) - 2013',
       'Population Estimate (as of July 1) - 2014',
       'Population Estimate (as of July 1) - 2015',
       'Population Estimate (as of July 1) - 2016'], axis = 1)
# Out:
#           GEOID  GEOID2        Geography Name  \
# 0   0400000US01       1               Alabama
# 1   0400000US02       2                Alaska
# 2   0400000US04       4               Arizona
# 3   0400000US05       5              Arkansas
# 4   0400000US06       6            California
# 5   0400000US08       8              Colorado
# 6   0400000US09       9           Connecticut
# 7   0400000US10      10              Delaware
# 8   0400000US11      11  District of Columbia
# 9   0400000US12      12               Florida
# 10  0400000US13      13               Georgia
# 11  0400000US15      15                Hawaii
# 12  0400000US16      16                 Idaho
# 13  0400000US17      17              Illinois
# 14  0400000US18      18               Indiana
# 15  0400000US19      19                  Iowa
# 16  0400000US20      20                Kansas
# 17  0400000US21      21              Kentucky
# 18  0400000US22      22             Louisiana
# ...

# %%
df3.to_csv('clean data game estimate 2017.csv', index=False)

# %%
df1.to_csv('clean game.csv', index= False)
